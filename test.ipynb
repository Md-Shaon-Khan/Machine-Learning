# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-Shaon-Khan/Machine-Learning/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world
