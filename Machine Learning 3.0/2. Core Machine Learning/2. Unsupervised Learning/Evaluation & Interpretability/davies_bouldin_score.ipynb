# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
import matplotlib.pyplot as plt

# Step 1: Load dataset
iris = load_iris()
X = iris.data

# Step 2: Evaluate clustering for k = 2, 3, 4, 5
k_values = [2, 3, 4, 5]
sil_scores = []
db_scores = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X)
    
    sil = silhouette_score(X, labels)
    db = davies_bouldin_score(X, labels)
    
    sil_scores.append(sil)
    db_scores.append(db)
    print(f"k={k} --> Silhouette Score: {sil:.3f}, Davies-Bouldin Index: {db:.3f}")


plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(k_values, sil_scores, marker='o')
plt.title("Silhouette Score vs k")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")

plt.subplot(1,2,2)
plt.plot(k_values, db_scores, marker='o', color='r')
plt.title("Davies-Bouldin Index vs k")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("DB Index")

plt.tight_layout()
plt.show()
# Out:
# k=2 --> Silhouette Score: 0.681, Davies-Bouldin Index: 0.404
# k=3 --> Silhouette Score: 0.551, Davies-Bouldin Index: 0.666
# k=4 --> Silhouette Score: 0.498, Davies-Bouldin Index: 0.754
# k=5 --> Silhouette Score: 0.493, Davies-Bouldin Index: 0.819
